# %%
# import libraries for data manipulation
import pandas as pd

# %%
# Let's read VIIRS csv sample data set into a DataFrame df

df = pd.read_csv('https://firms.modaps.eosdis.nasa.gov/content/notebooks/sample_viirs_snpp_071223.csv')

# %%
# show how many rows (records) and columns (values per record) we have

print ('FIRMS sample fire data contains %i rows and %i columns' % (df.shape[0], df.shape[1]))
df.shape
# Out:
# FIRMS sample fire data contains 74605 rows and 14 columns
# (74605, 14)

# %%
df.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0   0.05836   29.59085      295.64  0.38   0.59  2023-07-12         3
# 1   0.48765   31.50760      296.73  0.51   0.66  2023-07-12         3
# 2   2.15227   13.94524      305.26  0.51   0.49  2023-07-12         3
# 3   2.15681   13.94618      319.05  0.51   0.49  2023-07-12         3
# 4   2.15754   13.94131      301.13  0.51   0.50  2023-07-12         3
#
#   satellite instrument confidence version  bright_ti5   frp daynight
# 0         N      VIIRS          n  2.0NRT      275.15  0.83        N
# 1         N      VIIRS          n  2.0NRT      275.15  0.56        N
# 2         N      VIIRS          n  2.0NRT      287.94  1.08        N
# 3         N      VIIRS          n  2.0NRT      288.77  1.81        N
# 4         N      VIIRS          n  2.0NRT      288.17  1.81        N

# %%
df.tail()
# Out:
#        latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 74600  61.42408 -110.40578      350.48   0.4    0.4  2023-07-12      1950
# 74601  61.42510 -110.39867      336.03   0.4    0.4  2023-07-12      1950
# 74602  61.42733 -110.40780      328.53   0.4    0.4  2023-07-12      1950
# 74603  61.42834 -110.40069      338.45   0.4    0.4  2023-07-12      1950
# 74604  61.42936 -110.39356      339.52   0.4    0.4  2023-07-12      1950
#
#       satellite instrument confidence version  bright_ti5    frp daynight
# 74600         N      VIIRS          n  2.0URT      309.39  16.01        D
# 74601         N      VIIRS          l  2.0URT      308.08  32.98        D
# 74602         N      VIIRS          n  2.0URT      298.15  16.01        D
# 74603         N      VIIRS          n  2.0URT      302.81  32.98        D
# 74604         N      VIIRS          n  2.0URT      306.58  32.98        D

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74605 entries, 0 to 74604
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    74605 non-null  float64
#  1   longitude   74605 non-null  float64
#  2   bright_ti4  74605 non-null  float64
#  3   scan        74605 non-null  float64
#  4   track       74605 non-null  float64
#  5   acq_date    74605 non-null  object
#  6   acq_time    74605 non-null  int64
#  7   satellite   74605 non-null  object
#  8   instrument  74605 non-null  object
#  9   confidence  74605 non-null  object
#  10  version     74605 non-null  object
#  11  bright_ti5  74605 non-null  float64
#  12  frp         74605 non-null  float64
#  13  daynight    74605 non-null  object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 8.0+ MB

# %% [markdown]
# # **Canada**

# %%
import pandas as pd
df = pd.read_csv('https://firms.modaps.eosdis.nasa.gov/content/notebooks/sample_viirs_snpp_071223.csv')

# From 'Regional Coordinates' we can get Canada's approximate bounding box
# Canada coordinates: West South, East North as -150 40, -49 79

# copy() - will create a duplicate dataset with Canada data only
df_canada = df[(df['longitude'] >= -150) & (df['latitude'] >= 40) & (df['longitude'] <= -49) & (df['latitude'] <= 79)].copy()
print ('Canada subset contains %i records.' % len(df_canada))

# %% [markdown]
# **Example of vacation places without fires**

# %%
# !pip install geopandas
# !pip install cartopy
# Out:
# Requirement already satisfied: geopandas in c:\users\malhe\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\malhe\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\malhe\anaconda3\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\malhe\anaconda3\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\malhe\anaconda3\lib\site-packages (from geopandas) (2.1.4)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\malhe\anaconda3\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\malhe\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\malhe\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\malhe\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\malhe\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\malhe\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\malhe\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Collecting cartopy
#   Downloading Cartopy-0.24.1-cp311-cp311-win_amd64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\malhe\anaconda3\lib\site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\malhe\anaconda3\lib\site-packages (from cartopy) (3.8.0)
# Requirement already satisfied: shapely>=1.8 in c:\users\malhe\anaconda3\lib\site-packages (from cartopy) (2.0.6)
# Requirement already satisfied: packaging>=21 in c:\users\malhe\anaconda3\lib\site-packages (from cartopy) (24.1)
# Collecting pyshp>=2.3 (from cartopy)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#      ------------- ------------------------ 20.5/56.0 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 56.0/56.0 kB 737.6 kB/s eta 0:00:00
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\malhe\anaconda3\lib\site-packages (from cartopy) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\malhe\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\malhe\anaconda3\lib\site-packages (from pyproj>=3.3.1->cartopy) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\malhe\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Downloading Cartopy-0.24.1-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.0 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.0 MB 6.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.0 MB 10.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/11.0 MB 15.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.3/11.0 MB 19.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.7/11.0 MB 21.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/11.0 MB 22.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/11.0 MB 26.1 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 29.7 MB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#    ---------------------------------------- 46.5/46.5 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: pyshp, cartopy
# Successfully installed cartopy-0.24.1 pyshp-2.3.1

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from cartopy import crs as ccrs
from cartopy.feature import LAND, COASTLINE

# %%
df = pd.read_csv('https://firms.modaps.eosdis.nasa.gov/content/notebooks/sample_viirs_snpp_071223.csv')

# %%
df.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0   0.05836   29.59085      295.64  0.38   0.59  2023-07-12         3
# 1   0.48765   31.50760      296.73  0.51   0.66  2023-07-12         3
# 2   2.15227   13.94524      305.26  0.51   0.49  2023-07-12         3
# 3   2.15681   13.94618      319.05  0.51   0.49  2023-07-12         3
# 4   2.15754   13.94131      301.13  0.51   0.50  2023-07-12         3
#
#   satellite instrument confidence version  bright_ti5   frp daynight
# 0         N      VIIRS          n  2.0NRT      275.15  0.83        N
# 1         N      VIIRS          n  2.0NRT      275.15  0.56        N
# 2         N      VIIRS          n  2.0NRT      287.94  1.08        N
# 3         N      VIIRS          n  2.0NRT      288.77  1.81        N
# 4         N      VIIRS          n  2.0NRT      288.17  1.81        N
